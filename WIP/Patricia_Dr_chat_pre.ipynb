# %% [markdown]
# <a href="https://colab.research.google.com/github/Sug-ar-N-Spice/Dr.Chats/blob/Patricia/Patricia_Dr_chat_pre.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import re
import torch
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM, AutoModelForCausalLM
# !pip install -q gradio

import gradio as gr
from google.colab import drive
drive.mount('/content/drive')


! pip install sacremoses
! pip install transformers
! pip install datasets
! pip install torch

from typing import List, Dict
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from datasets import load_dataset
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.4/50.4 kB 2.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.3/42.3 MB 27.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 319.8/319.8 kB 21.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.7/94.7 kB 7.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.4/76.4 kB 5.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.0/78.0 kB 5.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 436.6/436.6 kB 26.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 141.9/141.9 kB 10.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 88.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.7/63.7 kB 5.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 3.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.2/73.2 kB 5.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.2/130.2 kB 8.6 MB/s eta 0:00:00
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-1-b1bd7adf11e6> in <cell line: 9>()
#       7 import gradio as gr
#       8 from google.colab import drive
# ----> 9 drive.mount('/content/drive')
#      10
#      11
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      98 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      99   """Mount your Google Drive at the specified mountpoint path."""
# --> 100   return _mount(
#     101       mountpoint,
#     102       force_remount=force_remount,
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     275             'https://research.google.com/colaboratory/faq.html#drive-timeout'
#     276         )
# --> 277       raise ValueError('mount failed' + extra_reason)
#     278     elif case == 4:
#     279       # Terminate the DriveFS binary before killing bash.
#
# ValueError: mount failed

# %%
import torch
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM, AutoModelForCausalLM

class STIChatbot:
    def __init__(self, summary_model="FalconsAI/medical_summarization",
                 qa_model="microsoft/BioGPT"):
        self.preprocessor = STIDataPreprocessor()
        self.summary_tokenizer = AutoTokenizer.from_pretrained(summary_model)
        self.summary_model = AutoModelForSeq2SeqLM.from_pretrained(summary_model)
        self.qa_tokenizer = AutoTokenizer.from_pretrained(qa_model)
        self.qa_model = AutoModelForCausalLM.from_pretrained(qa_model)

    def preprocess_data(self, df):
        return self.preprocessor.preprocess_dataframe(first_10_rows_df)

    def generate_summary(self, text):
        inputs = self.summary_tokenizer(text, return_tensors="pt", max_length=512, truncation=True)
        summary_ids = self.summary_model.generate(
            inputs["input_ids"],
            max_new_tokens=150,
            min_length=40,
            length_penalty=2.0,
            num_beams=4,
            early_stopping=True
        )
        return self.summary_tokenizer.decode(summary_ids[0], skip_special_tokens=True)

    def answer_question(self, context, question):
        prompt = f"Context: {context}\nQuestion: {question}\nAnswer:"
        inputs = self.qa_tokenizer(prompt, return_tensors="pt", truncation=True, max_length=512)

        # Calculate available tokens for the answer
        input_length = inputs["input_ids"].shape[1]
        max_new_tokens = min(100, 1024 - input_length)  # Assuming 1024 is the model's maximum context length

        output = self.qa_model.generate(
            inputs["input_ids"],
            max_new_tokens=max_new_tokens,
            num_return_sequences=1,
            do_sample=True,
            temperature=0.7
        )
        return self.qa_tokenizer.decode(output[0], skip_special_tokens=True)

# %%
dataset = load_dataset("ruslanmv/ai-medical-dataset")

# Select the first 10 rows of the dataset
first_10_rows = dataset["train"].select(range(1000000))
# Convert the first 10 rows to a pandas DataFrame
first_10_rows_df = first_10_rows.to_pandas()
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Resolving data files:   0%|          | 0/18 [00:00<?, ?it/s]
# Resolving data files:   0%|          | 0/18 [00:00<?, ?it/s]
# Loading dataset shards:   0%|          | 0/18 [00:00<?, ?it/s]

# %%
# to see what type of dataset this is
dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['question', 'context'],
#         num_rows: 21210000
#     })
# })

# %%
# to see what type of dataset this is
dataset["train"]["question"]
# Out:
# ['What is the resurgent sodium current in mouse cerebellar Purkinje neurons?',
#  'What isoform is a locus for inherited spinocerebellar at',
#  'What is the name of the study that focuses on the study of the drug-',
#  'What was the code for anaphylactic shock unspecified?',
#  'What is the cost of Fever Evaluation Cost and Time to Treatment in the General Surgery Patient?',
#  'What is the average cost of an FAL work-up?',
#  'What is the case-control study of young adult Singaporean males?',
#  'What was the average age of the study?',
#  'What is the name of the new drug that is used to threaten military readiness?',
#  'What is the name of the dissociative drug that is sold as a white powder?',
#  'What was the name of the military personnel in FY 2010?',
#  'What was the rate of use/abuse of Schedule II-IV prescription medications in U',
#  'What is the name of the case for 166 patients?',
#  'What is the largest published case series evaluating SGB?',
#  'What is the name of the class of Veterans with multiple risk factors?',
#  'What was the smallest group of primary care patients identified using?',
#  'What is the name of the Special Operations Forces that are a part of the U.',
#  'How many subjects per year were injured in musculoskeletal injuries?',
#  'What is the name of the review of Mild Traumatic Brain Injury Diagnostics?',
#  'What is a common battlefield and in-garrison injury caused by transmission of mechanical forces to',
#  'What is the primary care experience of Veterans Affairs Primary Care Patients?',
#  'What is the most preferred treatment approach?',
#  'What is the name of the Veteran Sample?',
#  'What was the symptom severity of post-traumatic stress disorder and depression?',
#  'What is the structure of the steroidal glycoalkaloids?',
#  'What is the name of the steroidal glycoalkaloids found in Lilium species?',
#  'What is the Chinese-language Brief Sensation Seeking Scale?',
#  'What is the most commonly used language in the Western Pacific and Southeast Asia?',
#  'What is the morphological normality of Sperm under high magnification?',
#  'How many spermatozoa were graded into four groups?',
#  'What is the lowest pertussis toxin antibody in two regional cohorts of Canadian',
#  'What is the lowest limit of quantification of the anti-PT assay?',
#  'What is the name of the Soluble ST2 in heart failure?',
#  'What is soluble ST2?',
#  'What is an improved Flow Cytometric Immunobead Array to Detect',
#  'What is the FCIA assay?',
#  'What is the name of the BACTERIA IDENTIFICATION?',
#  'What is the name of the method that is used to identify bacteria for the diagnosis of bloodstream',
#  'What is the quantitative comparison of stress fibers and Focal Adhesions?',
#  'What is the name of the software used to quantify actin SFs?',
#  "What is the IMC's name?",
#  'What was the main cause of the inflammatory CD4+ T cells?',
#  'What is the CpG-Oligodeoxynucleotide for',
#  'What is the cellular receptor for CpG-ODN in mammalian cells',
#  'What is Clostridium difficile Isolates from Human Fecal Samples?',
#  'What was the most common type of isolates in human and meat?',
#  'What is the business impact analysis used to describe hospital disaster response?',
#  'What was the estimated water consumption in the hospital?',
#  'What is the Behavioral Study of the Salicylate-Induced Tinnitus',
#  'What is the tinnitus rat model?',
#  'What is the name of the two (Partly) Distinct Components of Cardiovascular',
#  'What are the benefits of PA and CRF in the prevention of CV disease and risk factors?',
#  'What is the name of the major Markers of Cardiovascular Risk?',
#  'What is the main reason for the decline in PA patterns?',
#  'How many steps in the right direction are the results from the first American Heart Association Scientific Sessions Walking',
#  'How many steps were walked by participants during the Walking Challenge?',
#  'What is the effect of Virtual Speaker Density and Room Reverberation on Spati',
#  "What was the reverberant stimulus generated by a sequential activation of LED'",
#  'What is the endoscopic endonasal approach?',
#  'What is the name of the tumor that recurred along the trigeminal nerve',
#  'What type of Lymphoma is a case of primary Dural Lymphoma',
#  'What is a subentity of primary leptomeningeal lymphom',
#  'What is the cause of Cerebral Infarction Caused by Pituitary',
#  'What is the cause of the onset of unconsciousness?',
#  'What is the total resection of large Cervical Intramedullary Ep',
#  'What is the most common intramedullary tumor in the spinal cord?',
#  'What is the Clinical Results of Anterior Odontoid Screw Fixation for Type',
#  'What was the mean hospital stay in 4 patients?',
#  'What is the name of the removing of Bloody Cerebrospinal Fluid in',
#  'How many patients were assigned to the LD group?',
#  'What is the second-generation wallis interspinous Dynamic Stabilization Device',
#  'What was the JOA score at 3, 12, and 24 months after surgery?',
#  'What is the Endovascular Treatment of Intracranial Dural Arteriovenous F',
#  'How many patients were treated with TA?',
#  'Idiopathic Scoliosis.',
#  'What is the main hypothesis for idiopathic scoliosis?',
#  'What is the name of the systematic review of Carmustine Wafers?',
#  'What was the aim of this study?',
#  'What is a multilevel approach to Oxidative Stress?',
#  'What was the mean GSH-Px value in a population at high risk?',
#  'What is CTLA4-Ig Preserved?',
#  'What is CTLA4-Ig used in clinical trials?',
#  'What is the association between alcohol-cue modulated startle reactions and drinking behavior in alcohol',
#  'What is the effect of a differential medication effect on alcohol dependence?',
#  'What can Continuous Subcutaneous Insulin Infusion improve health-relative quality of life in',
#  'What was the first case of continuous subcutaneous insulin infusion?',
#  'What is the complete mitochondrial genome of the spinner shark Carcharhinus brevi',
#  'What was the average value of whole mitogenome?',
#  'What is the name of the microRNAs in patients with polycystic ova',
#  'What was the target of dys-regulated miRNAs?',
#  'What is the name of the publication that published Nanoscience Advances in Rheumatology',
#  'What is the name of the mini-series that will provide an overview of nanoscience?',
#  'What is the second-line treatment of Advanced Gastric Cancer?',
#  'What was the risk of death decreased by 18%?',
#  'What is the risk factor for Acute Stroke among South Asians?',
#  'What is the most common type of stroke in South Asians?',
#  'What is the name of the non-native snake Envenomations in the U.',
#  'How many human exposures were there between 2005 and 2011?',
#  'What is the name of the biocompatible Cinnamaldehyde Functionalized Magnetit',
#  'What is the bioactive component of cinnamon?',
#  'What is the name of the Vaccine Coverage Pattern of Streptococcus',
#  'What is the most common serotype in SAARC countries?',
#  'What is the effect of the B19 and VP1 Unique Region on Tight Junction of',
#  'What is the secreted phospholipase A2 (sPLA2)',
#  'What is the population-based case-control study?',
#  'What was the most proximate prescription prior to the index date?',
#  'What is the name of the sample that was used to describe the testosterone Traject',
#  'What is the average exposure to testosterone associated with?',
#  'What is the interplay between inflammatory cytokines and the endocannabin',
#  'What is the endocannabinoid system mediated control of synaptic',
#  'What is Safe and Effective for Patients with Hepatocellular Carcinoma and Portal Hyper',
#  'What is the most common reason for the mortality rate of HCC patients?',
#  'What is a Counter-Selection Marker?',
#  'What is the name of the rpsL mutation that encodes the ribo',
#  'What is the Japanese Health Database?',
#  'What was the main limitation of the study?',
#  'What is FeS clusters used for molybdenum cofactor biosynthesis?',
#  'What is the only second row transition metal essential for biological systems?',
#  'What is the cause of inflammasome signaling in human ARPE-19 cells?',
#  'What is the main role of RPE in maintaining photoreceptors?',
#  'MiR-34a Inhibits Migration and Invasion of Tongue Squa',
#  'What is the name of the tumor suppressor gene in TSCC?',
#  'What is the primary cause of Carotid Intima-Media Thickness?',
#  'What is the distinct coronary artery disease risk factor?',
#  'What is the estimated medical costs associated with first-ever ischemic stroke patients transferred to?',
#  'What was the mean total medical cost per patient?',
#  'What causes signaling deficits in corticostriatal circuitry that are reversed by',
#  'What is the dmPFC BDNF infusion?',
#  'What is the miR-290-295/miR-371-373 Cluster Family',
#  'What is the miR-371-373 homolog in human?',
#  'What is the name of the Nanoconjugate?',
#  'What is the potential for cell targeting and therapeutic effects?',
#  'What is the Nintendo Wii Balance Board?',
#  'What was the difference in error between the WBB and AMTI force plate?',
#  'What is the name of the sensorized nuss bar for patient-specific treatment of Pe',
#  'What is the sternum characterized by?',
#  'What did the change in Catastrophizing and Depressed Mood During and',
#  'What is the focus of the current study?',
#  'What is the association between DAPK1 Promoter Methylation and Cervical',
#  'What is the DAPK1 promoter gene?',
#  'What is the name of the program that is a large public health ART program?',
#  'How many patients were enrolled in the ART program?',
#  'What is an evidence-based method for examining and reporting cognitive processes in nutrition research?',
#  'What is the CHC model of intelligence?',
#  'What is the contribution of psychosocial factors to the Association between Socioeconomic position and Takeaway',
#  'What was the average age of a person in Brisbane?',
#  'What is the name of the long-term follow-up of adult men born with hypos',
#  'How many patients were treated in Sweden?',
#  'What is the role of Actual Self versus Ideal Self in Implicit Self-Estee',
#  'What is the relationship between implicit self-esteem and depression?',
#  'What is the cause of Mitochondrial disturbances in HIV pregnancies?',
#  'What was the main objective of this study?',
#  'What is the stigma in rural Uganda?',
#  'What is the main reason for the increase in internalized stigma among PLHIV?',
#  'What is the name of the Detection of Colorectal Cancer?',
#  'What is the leading cause of cancer related death in Europe and the USA?',
#  'What is the name of the Species that are scavenging in rats?',
#  'What is the most important mechanism by which SS protects against GJIC inhibition?',
#  'What is the result of a Randomized placebo-controlled placebo-controlled trial?',
#  'What is the name of the plant that is derived from?',
#  'What is the name of the Virus that is a Respiratory Syncytial',
#  'What is the leading cause of lower respiratory tract diseases?',
#  'What is the fibrocartilage variation in human anterior cruciate ligament insertion',
#  'What was the UF layer divided into?',
#  'What is the focus of multiprofessional teamwork in work-related medical rehabilitation for patients with chronic',
#  'What is the significance of multiprofessional teamwork for successful multimodal rehabilitation?',
#  'What is the high uptake of systematic HIV Counseling and Testing and TB Symptom',
#  'How many patients were diagnosed with HIV during the first 6 months?',
#  'What is the surface-assisted laser desorption/ionization mass spectrome',
#  'What is the main application for the SALDI-MS?',
#  'What method of casting is used to preserve alveolar microstructure?',
#  'What was the hydroxyproline content of decellularized lungs similar to native lung?',
#  'What is the main cause of a tumor cell-induced platelet aggregation?',
#  'What is the name of the plant used in traditional medicine?',
#  'What is the effect of Perioperative Supplementation with Omega-3 Fatty Acids on Le',
#  'What is the effect of oral n-3 FA on surgical patients?',
#  'What is the effect of Green Tea Consumption on cognitive Dysfunction in the Elderly',
#  'What is green tea known to have health benefits for humans?',
#  'What is cystatin C-derived equations used for?',
#  'What is the average serum concentration of cystatin C?',
#  'What is the effect of Growth Hormone Replacement on Cognitive Function in Rats with Traumatic',
#  'What was the effect of growth hormone on cognitive dysfunction?',
#  'What is the study of Combined and Sequential Surgery for Proliferative Diabetic',
#  'How many eyes were enrolled in the combined surgery group?',
#  'What is the name of the Editorial?',
#  'What is the name of the novel strategies that have emerged in the late 20th century?',
#  'What is the ECF Sigma Factor SigE?',
#  'What is the sigE gene that is dispensable for replication in human pneumocyte',
#  'What is the secondary transmission of Cryptosporidium parvum?',
#  'What was the probable secondary transmission rate in the 2012 outbreak?',
#  'What is the new model to reduce unnecessary Prostate Biopsies',
#  'What was the target of the study?',
#  'What is the name of the exercise that prevents Cisplatin-Induced Mus',
#  'What is the main concern in cancer patients?',
#  'What is the effect of oralally administered beta-glucan on Innate Immune Response',
#  'What is the name of the study that did the study do not support?',
#  'What is a Novel DPP-4 Inhibitor?',
#  'What is the name of the DPP-4 inhibitor MK626, which has appropriate pharma',
#  'What is the effect of Intra-Aortic Balloon Counterpulsation Pump',
#  'What was the primary endpoint of AMI?',
#  'What is the goal of Iranian hospitals?',
#  'What was the most common type of hospital in Iran?',
#  'What is the current use of platelet-Rich Plasma?',
#  "What is the regulatory process for PRP preparation systems described in the FDA's 21 CFR 12",
#  'What is the clinical effect of Protein and Amino Acid Supplementation on Building Muscle Mass',
#  'What is the main reason for the loss of mobility in elderly people?',
#  'What is the effect of increased orbitofrontal cortex activation associated with?',
#  'What is the main limitation of this study?',
#  'What is the risk of a pre-Eclampsia and Gestational',
#  'What is the aetiology of pregnancy?',
#  'What is the name of the Virus-Like Particles derived from?',
#  'What is the name of the group that produced RV-VLPs?',
#  'What is the surgical procedure?',
#  'What was the rate of a new infertility problem after resection of ',
#  'What is the effect of a contraceptive containing drospirenone and',
#  'What is the effect of combined oral contraceptives on the systemic blood pressure, metabolic variables',
#  'What is the outcome of non-anonymous oocyte donation?',
#  'How many oocyte donation pregnancies were compared to in vitro fertilization',
#  "What is the Huntington's Disease-Related Cardiomyopathy?",
#  'What is the cause of the huntingtin protein to aggregate?',
#  "What is Magnesium's protection?",
#  'What is the effect of magnesium on AD?',
#  'What is the antiinflammatory effect of Phytosterols in Experimental Murine Colitis',
#  'What was the effect of phytosterols on prevention/induction/remission in ',
#  'What is the outcome of the Therapeutic Hypothermia after Pediatric Cardiac Arrest',
#  'What is the primary outcome of the Vineland Adaptive Behavior Scales Second',
#  'What is the cause of blood-brain barrier dysfunction in mice?',
#  'What is the key event in the development of many central nervous system diseases?',
#  'What is the name of the DPP-4?',
#  'What was the expression pattern of DPP-4 expressed in human and mouse islets?',
#  'What is the negative regulation of GYF Protein 2 on Insulin-Like Growth Fact',
#  'What is the role of IGF1R signaling pathway in the neuropathogenic process of',
#  'What is the result of an examination of camptocormia assessment?',
#  'What is the name of the pathology that debilitates patients in their daily life?',
#  'What is the Prevalence and Factors for Cancer Screening Behavior among People with Se',
#  'What is the percentage of PSMI screening behavior among PSMI?',
#  "What is the primary Sjogren's syndrome?",
#  'What was the name of the group 1/CV?',
#  'What is the name of the study that identifies the causes of Incidence of In',
#  'What was the primary approach at cesarean delivery?',
#  'What is the senescence of human primary thyrocytes?',
#  'What is the effect of OIS on thyroid carcinoma?',
#  'What is the therapeutic effect of a TM4SF5-specific monoclonal',
#  'What is the TM4SF5-specific monoclonal antibody presumed to serve',
#  'What is Picropodophyllin responsible for?',
#  'What is the anticancer drug undergoing clinical development in NSCLC?',
#  'What is a Polysaccharide Co-Polymerase Involved',
#  'What is the chromosomal Pss-I cluster?',
#  'What is the expression of XPG Protein in the Development, Progression and Prognos',
#  'What was the XPG protein expression in GC?',
#  'What is the response to the Opportunistic Pseudomonas ',
#  'What is the common cause of healthcare-associated infections?',
#  'What is the 5-Alpha-reductase inhibitor?',
#  'What is the effect of 5-ARIs on the androgen-mediated angiogenic',
#  'What is the comparison between Shockwave Lithotripsy and Flexible Ureteroscopy',
#  'What was the most common stone location in the SWL group?',
#  'What is the name of the drug used in the study?',
#  'What was the primary outcome of the trial?',
#  'What is the key cost driver of Oncology Inpatient Treatment?',
#  'What was the primary aim of the study?',
#  'What is the 2,4-Dienone Motif?',
#  'What was the MIC of the two derivatives?',
#  'What effect did Scutellarin have on Isoprenaline-In',
#  'What is the major active component of breviscapine?',
#  'What is the name of the cellular transport mechanism of Cytotoxic Metallodrugs',
#  'What is the name of the group of metal-containing coordination compounds that are on the market?',
#  'What is the name of the five new Iridoids from Roots of Salvia digitalo',
#  'How many new iridoids were isolated from the roots of Salvia digitaloides?',
#  'What is the Prognostic Indicator in Lung-Dominant Connective',
#  'What is a new concept for classifying the subset of patients with interstitial pneumonia',
#  'What is the effect of alpha-Targeted Radiation Therapy on Gene Expression?',
#  'What is the molecular basis of enhanced cell killing?',
#  'What is the rHSP70?',
#  'What is the name of the protein that induced Th1-type of cellular responses in',
#  'What is the name of the CD4 T Cell Editing?',
#  'What is a promising method for HIV-1 gene therapy?',
#  'What is the name of the brain system that is large-scale?',
#  'What is the paradigm for understanding brain functioning?',
#  'What is the vertically organized brain?',
#  "What is the brain's vertical organization described as fundamental to cognitive and behavioral control?",
#  'What is the Small-World Organization of Large-Scale Brain Systems and Relationships',
#  'What is the name of the small-world organization?',
#  'What is the structure and function of large-scale Brain Systems?',
#  'What is the function of large-scale brain systems presented?',
#  'What is the activity of atypical parietal lobe activity to sublim',
#  'What is the main factor in the AUD response?',
#  'What is the Editorial of the Editorial entitled Unlocking the Potential of Stem Cell',
#  'What is the role of pigment epitheliumderived factor?',
#  'What is the potential therapeutic target for Pancreatic Cancer?',
#  'What was the first study that showed increased A-A8 expression associated with?',
#  'What is the province of Brescia?',
#  '',
#  'What is the potential for a controlled study?',
#  '',
#  'What is the name of the treatment that is not used for anti-cytokine biologic treatment',
#  'What was the anti-IL-17 antibody secukinumab and the anti-IL',
#  'What is the name of the disease that is characterized by Gastrointestinal manifestations?',
#  'What is the inflammatory disorder that is characterized by?',
#  "Behcet's syndrome: a critical digest of the 2013-2014 literature.",
#  'What is the most important factor in BS?',
#  "What type of thrombus is Behcet's syndrome?",
#  'What is the name of the BS patient who had a right ventricular throm',
#  "What is the name of the disease that preceded Behcet's syndrome and pregnancy?",
#  'What is the outcome of pregnancy in BD patients?',
#  'What is the name of the electronic medical record-based disease activity index?',
#  'What is the mean total run-time for the EMRAI shorter than that required to administer',
#  "Vein wall imaging in Behcet's syndrome?",
#  '',
#  "What is the self-criticism in Behcet's disease?",
#  '',
#  'What prevents the development of cardiomyopathy in type 2 diabetic mice?',
#  'What is the name of the type 2 diabetes mellitus-induced cardiomyopathy?',
#  'What is critical to the Protective Immune Response during Chemically Induced Squam',
#  'What is the main cause of chronic inflammation?',
#  'What is the name of the Activation of Neuronal and Astrocytes',
#  'What is the name of the neuropathic pain model?',
#  'What is the name of the patient with disorder of Sex Development?',
#  'What is the main barrier to a better understanding of how patients should be evaluated and treated?',
#  'What is the effect of oral supplementation on the respiratory burst function of innate immune',
#  'What is FPP reported to act as an antioxidant?',
#  'What is the name of the study that examined Naivety of T Cells in In',
#  'What is the name of the migratory pathways of naive and memory T',
#  'What is the role of the Intestinal Microbiota?',
#  'What is the name of the gastrointestinal disease that remains one of the most frequent in the neon',
#  'What is the population-based IBD Cohort?',
#  'How many patients had measured hemoglobin levels at 12 months?',
#  'What is Clostridium difficile and Pediatric Inflammatory Bowel Disease?',
#  'What was the most common type of infection in pediatric patients?',
#  'What is the Associated with Non-Calcified Plaque Burden in Patients with Corona',
#  'What was the goal of the study?',
#  'What is the NG2 Proteoglycan in a Rat Model of',
#  'What was the most reliable radiological parameter for detecting response to immunotherapy?',
#  'What is the name of the POSTOPERATIVE CYSTOGRAM FIND',
#  'What is the mean BNPS ratio for continent patients?',
#  'What is an image-based genetic assay?',
#  'What is the role of IL-27 in antiviral immunity?',
#  'What is the role of nanoparticles in Pulmonary Diseases?',
#  'What is the name of the two-side role of nanoparticles in pulmonary diseases',
#  'What is the name of the novel RGD-Modified Lipid-Polymer Hy',
#  'What was the lipid-shell and polymer-core hybrid nanoparticles modified by',
#  'What is the average FSH level of females?',
#  'What is the follicular fluid produced during folliculogenesis?',
#  "What is the effect of PXR's 3'-UTR?",
#  'What is the main component of the nuclear receptor superfamily?',
#  'What is the name of the study that focuses on the biological function and clinical use of CD',
#  'What is CD147 known as?',
#  'What is the genetic difference between gender and colorectal cancer?',
#  'What is the name of the group that analyzed 116 CRCs?',
#  'What is the effect of APE1 T2197G polymorphism on APE',
#  'What is the effect of APE1 T2197G?',
#  'What is the corrective effect of Age-Related Changes in the Face?',
#  'What are injectable hyaluronic acid-based fillers and neurotoxins?',
#  'What is the safety of Psoriasis Therapies?',
#  'What is the safety profile of two therapeutic classes widely used in the treatment of psori',
#  'What is the therapeutic development in Psoriasis?',
#  'What is the name of the therapeutic candidate that is targeted by Janus kinase',
#  'What is the role of TNF Inhibitors in Psoriatic Disease?',
#  'What is the main form of treatment for psoriasis?',
#  'What is a Zinc Finger Protein?',
#  'What is Celastramycin A?',
#  'What is the application of Whole-Tumor Texture Analysis of Diffusion-We',
#  'What was the entropy of high-grade gliomas?',
#  'What is the IgM-Antibodies against Phosphorylcholine in Mother',
#  'How many mothers were born at term?',
#  'What is the Onset of Arthritis in a Mouse Model?',
#  'What is the cause of Psoriatic arthritis?',
#  'What is the Genome-Wide In-Silico Cis-Regulatory Module Pre',
#  "What is CisMiner's method to detect putative CRMs?",
#  'What is the name of the Activated Subgroup of Regulatory T Cells Enrich',
#  'What is the phenotype of LAP+ Tregs?',
#  'What is the main characteristic of nonylphenol and bisphenol A accumulation by fish?',
#  'What is the concentration of NP and BPA in wild freshwater fishes?',
#  'What is the best luteal phase support for each IVF stimulation protocol?',
#  'What is the best dose and way of progesterone?',
#  'What is the menstrual cycle regularization following d-chiro-inosi',
#  'What is the effect of DCI on menstrual cycle regularity in PCOS women?',
#  'What is the role of free triiodothyronine in patho',
#  'What was the mean TSH level after the increase of LT4?',
#  'What is the name of the small-molecule and nanoparticle toll-like Recept',
#  'What is the primary prerequisite for biological activity in this family of compounds?',
#  'What is the language of Mandarin?',
#  'What is the relationship between stuttering loci and lexical tone in Mandarin',
#  'What is the postconcussion Symptom Scale?',
#  'What was the factor structure of a 19-item Post-Concussion ',
#  'What is the purpose of Motivational Interviewing?',
#  'What is motivational interviewing?',
#  'What is Nfluenza 101?',
#  'What is the influenza season?',
#  'What is the target of Novel 2-Amino-Chromene-Nitrile',
#  'What is the anti-apoptotic protein Bcl-2 a well-known',
#  'What is the Acute Respiratory Distress Syndrome?',
#  'What was the primary outcome of the study?',
#  'What is the name of the substance in drinking water?',
#  'What was the median concentration of chromium in drinking water?',
#  'What is the impact of a collaborative interprofessional learning experience on medical and social work students in',
#  'What is the main model of health care?',
#  'What is the effect of home-based Interval Walking Training on Thigh Muscle Strength and',
#  'What was the average age of the IWT subjects?',
#  'What is the name of the bio-nanomachine that is used for FRET',
#  'What is the name of the bio-nanomachine that runs on thermal noise?',
#  'What is the TGF-Beta Downregulation of Distinct Chloride Channels',
#  'What is the CFTR regulated by?',
#  'What is the name of the association between Blood Lipid Levels and Personality Traits in',
#  'What is the name of the study that examined the association between lipid levels and personality traits in',
#  'What is the cost of antibiotic resistance in Escherichia coli?',
#  'What is the average cost of antibiotic resistance in terms of intrinsic growth in the antibiotic-free experimental',
#  'What is the Inner Foreskin of Healthy Males at Risk of HIV Infection?',
#  'What is the difference between inner foreskin stratum corneum and outer fore',
#  'What is the mechanism of immunoevasion?',
#  'What is the role of prostate tumor-derived exosomes in prostate cancer?',
#  'What is the Human Mesenchymal Stem Cell Tubule Communication Network?',
#  'What is the first study demonstrating that MSCs from human arteries constitutively interact',
#  'Clinical management of Staphylococcus aureus Bacteremia: A Review.',
#  'What was the name of the study that was conducted from January 1990 through May 2014?',
#  'What is the name of the patient who was diagnosed with a relapse in the ',
#  'What was the last follow-up date for mortality?',
#  'What is the name of the Acupuncture for Chronic Knee Pain?',
#  'What was the primary outcome of the trial?',
#  'What is the effect of a postdischarge Virtual Ward on Readmission or Death for',
#  'What was the primary outcome of the study?',
#  'What is the treatment regime for pulmonary arterial hypertension?',
#  'What is the name of the treatment that has been approved for PAH and CTEPH?',
#  'What is the effect of hormone therapy on blood pressure?',
#  'What was the effect of oral therapy on blood pressure in normotensive women?',
#  'What is the primary immunodeficiency of human T follicular helper cells',
#  'What is the key feature of the vertebrate immune system?',
#  'Multiple intestinal atresia with combined immune deficiency.',
#  'What is the tetratricopeptide repeat domain 7A gene?',
#  'What is the average evaluation of anesthesiologists?',
#  'What was the median ratio of scores for residents in the department?',
#  'What is the name of the Malignant Hyperthermia Association of the United States?',
#  'How many AMRA reports met our inclusion criteria?',
#  'What is the Hepatic Expression of Vitamin D Receptor Inversely Associated with',
#  'What was the hepatic expression of VDR protein assessed by western blot?',
#  'What is the main predictor of stroke?',
#  'What is the mean follow-up time for the plasma total T, DHT and E2',
#  'What is the effect of Spinal Cord Compression on Vascular Blood Flow and Perfusion',
#  'What is the name of the three-dimensional finite element fluid-structure interaction model of the',
#  'What is the name of the T. cruzi Clade?',
#  'What is the name of the group of trypanosome parasites that comprises T.',
#  'What is the primary cause of extracapsular spread?',
#  'What is the single-most prognostic clinical variable in oral squamous',
#  'What is the fidelity of miRNA-378a-5p?',
#  'What is the name of the molecule that is associated with tumourigenesis and metastas',
#  'What is an anti-IGF-1R antibody?',
#  'How many patients were enrolled in the phase I clinical trial?',
#  'What is the first-line bevacizumab-containing therapy for advanced breast cancer',
#  'What was the primary end point of the study population?',
#  'What is the impact of low-grade toxicity in older people with cancer undergoing chemotherapy?',
#  'What was the average age of a patient in a central London hospital?',
#  'What is the effect of High Intensity Exercise on Disease Activity and Cardiovascular Risk in',
#  'What is the primary outcome of the study?',
#  'What is the Tumour Type or Grade of Tumour?',
#  'What is the HCMV protein expression in?',
#  'What is the name of the Superoxide Dismutase that protects against Brain',
#  'What is an isoform of SOD normally found both intra- and extra-cellularly',
#  'What is Protective to In Vitro and In Vivo Experimental Diabetic Neuropathy',
#  'What was the pathogenetic role of VEGF in long-term retinal and kidney',
#  'What is the risk of Atrial Fibrillation in Taiwan?',
#  'What is the HO-1 polymorphism?',
#  'What is the CXCL12 G801A polymorphism associated with?',
#  'What is the CXCL12 G801A polymorphism?',
#  'What is the diagnostic value of a Rec-ELISA?',
#  'What is the cause of congenital toxoplasmosis in newborns?',
#  'What is the Adjuvant Potential of Selegiline in Attenuating Organ Dys',
#  'What is an anti-Parkinson drug?',
#  'What is the name of the infants with postnatal or congenital Cytomegal',
#  'What is the leading cause of long-term sequelae?',
#  'What is common mental disorder symptom among patients with Malaria Attending Primary Care in Ethiopia?',
#  'What was the mean age of the participants?',
#  'What is the antimicrobial peptide LL-37?',
#  'What was the cytotoxicity of LL-37 determined by?',
#  'What is the cause of a cutaneous adverse reaction to calcium channel blockers?',
#  'What was the most common dermatologic manifestation?',
#  'What is the effect of topical anti-inflammatory treatments on atopic dermatitis',
#  'What is the main treatment for AD?',
#  'What is fractional exhaled nitric oxide associated with asthma control in children?',
#  'What was the most important way to achieve and maintain asthma control?',
#  'What is the concentration of IL-35 in plasma of asthma patients?',
#  'What is the plasma level of IL-35 in asthmatic patients?',
#  'What is the name of the cell that is involved in the development of airway remodeling?',
#  'What was the purpose of the study?',
#  'Immunotherapy in food allergy: towards new strategies.',
#  'What is the standard treatment for managing food allergies?',
#  'What is the effect of the calcium channel blockers Phalphabeta and omega-',
#  'What was the Imax of Phalpha1beta and omega-conotoxi',
#  'What is the name of the Combined Model of Depression in Rats?',
#  'What was the effect of chronic administration of tricyclic antidepressant?',
#  'What is the result of endoscopic resection?',
#  'How many lesions were treated by endoscopic resection?',
#  'What is the stent for endoscopic ultrasound-guided drainage of pancreatic fluid',
#  'What was the goal of the study?',
#  'What is the new metal stent with anti-migration features?',
#  'What was the median dysphagia-free time after stent placement?',
#  'What is the European Society of Gastrointestinal Endoscopy?',
#  'What is the official guideline of the European Society of Gastrointestinal Endoscopy',
#  'What is the name of the microstructure analysis of Enamel in Permanent and Deciduous',
#  'What was the mean prism diameter in deciduous teeth?',
#  'What is the postoperative Morbidity Index?',
#  'How many ACS-NSQIP patients were undergoing PD from 2005 to 2011?',
#  'What is the result of galactose-1-phosphate uridyl',
#  'What is the significance of endogenous galactose production?',
#  'What is the VITdAL-ICU Randomized Clinical Trial?',
#  'What was the primary outcome of the trial?',
#  'What is the relationship between antibiotic consumption and socio-demographic factors?',
#  'What was the OR of antibiotic prescription?',
#  'What is the primary prevention of CVD?',
#  'What is the effect of dietary advice on adults without existing CVD or increased CVD risk',
#  'What is the Validity of Job Exposure Matrix for Psychosocial Factors at',
#  'What was the name of the study that used two large population surveys?',
#  'What is Clusterin as potential predictive biomarkers for Severe Hand, Foot',
#  'What is the cause of widespread concerns in China?',
#  'What is the effect of interhemispheric functional coordination in electroconvulsive',
#  'What is the most rapid and effective therapy for depression?',
#  'What is the entorhinal cortex induced by maternal immune activation?',
#  'What is the main cause of schizophrenia?',
#  'What is the term for Corneal blindness?',
#  'What is the most effective treatment for advanced corneal disease?',
#  'What is the Associated with a Paradoxical Gain of Muscle Function In Vivo',
#  'What is the most common disease entity among non-dystrophic skeletal muscle con',
#  'What is the use of Surrogate Endpoints in Regulating Medicines for Cardio',
#  'What is the mean score of the questionnaire?',
#  'What is the name of the type of transmission of the Influenza B Virus in Household',
#  'What is the importance of small droplet nuclei "aerosols" in',
#  'What is the experimental model for Extended-Release Felodipine Disposition Ex',
#  'What was the aim of the study?',
#  'What is Caenorhabditis elegans?',
#  'What is the name of the fungi that is a severe threat to the life of',
#  'What is the name of the organization that provides technical assistance for multidrug-resist',
#  "What is the name of the article that was published in the Editors' Summary?",
#  'What type of patients were in Malaysia?',
#  'What was the most predominant genotype in both infected and healthy blood samples?',
#  'What is the name of the patent Corpus that is annotated chemical patent?',
#  'How many patents were annotated by annotator groups?',
#  'What is the CT-Based Attenuation Correction in I-123-Ioflu',
#  'What was the maximum area under the ROC curve?',
#  'What is the state of the art treatment of progressive or refractory multiple myel',
#  'What is the incidence of MM?',
#  'What is the treatment of SIADH in small cell lung cancer?',
#  'What was the cause of the seizure triggered by hyponatraemia?',
#  'What is the LSEPAELTDAVK Peptide?',
#  'What is the LSEPAELTDAVK peptide?',
#  'What is the spectrum of Clinicopathologic Manifestations and Molecular Pathogenesis?',
#  'What is the name of the monoclonal light chain-associated proximal tub',
#  'What is Langerhans Cell Histiocytosis?',
#  'What is the name of the disease that has been debated in the past?',
#  'What is the name of the lobular Neoplasia?',
#  'What is the pleomorphic form of lobular carcinoma in situ?',
#  'What is the Algorithmic Approach to a Heterogeneous Group of Disorder',
#  'What is the etiologically and morphologically heterogeneous group',
#  'What is a Cutaneous Clear Cell Malignancy?',
#  'What is the rare clear cell malignancy?',
#  'What is the name of the earliest Imitator of Mycosis Fungoides',
#  'What is the most common primary cutaneous lymphoma?',
#  'What is the name of the CD4 that is a small/medium T-C',
#  'What is a provisional and controversial entity with a broad differential diagnosis?',
#  'What is the Diagnosis?',
#  'What is the cause of the disease?',
#  'What is the name of the study that focuses on the phenotype of Sple',
#  "What is the spleen's morphologic, immunophenotypic,",
#  'What is the smallest B-Cell Lymphoma of the Prostate?',
#  'What is the most common subtype of the prostate?',
#  'What is the name of the bacterium that is characterized by metastatic Renal Cell',
#  'What is the only opportunity to obtain diagnostic tissue to diagnose and subclassify RCC?',
#  'What is the Tumor of the Bladder?',
#  'What is the inflammatory myofibroblastic tumor called?',
#  'What is the urinary Bladder?',
#  'What is a rare, reactive response to an ischemic insult?',
#  'What is the Correlation of Proteinuria with Podocyte Foot Process Efface',
#  'What is the most significant correlation between proteinuria and foot process effacement?',
#  'What is the biotechnologically relevant polyamide family?',
#  'What was the polyamide consisting of aspartic acid and arginine?',
#  'What is the name of the study that analyzed resistance profiles of Acinetobacter baum',
#  'What was the increase in MIC50 of imipenem-resistant isolates?',
#  'What is the Growth Factor-Induced, Spatially Organizing Cyto',
#  'What is the PLS zone maintained in?',
#  'How Kinetochores CCAN Resist Force?',
#  'What is the component of the CCAN?',
#  'What is the name of the pregnancy that is a part of the Diabetic pregnancy?',
#  'What is the new definition of GDM?',
#  'STAT3: A Novel Molecular Mediator of Resistance to Chemoradiotherapy',
#  'What is the main cause of CRT?',
#  'What is the future of Glioblastoma Therapy?',
#  'What is the current standard of care for glioblastoma?',
#  'What is the name of the ATP-Binding Cassette Transporters',
#  'What is the potential for successful cancer chemotherapy?',
#  'What is the name of the SUMO and KSHV Replication?',
#  'What is the name of the SUMO system that is a reversible post',
#  'What is the term for Positron Emission Tomography?',
#  'What is the name of the neoplastic treatment that is a cornerstone of',
#  'What is the name of the off-label prescription of genetically modified organism medicine in',
#  'What is the name of the first human medicine containing a genetically modified organism?',
#  'What is the name of the Inquiry Into the Histories of Psychi',
#  'What is the Cronbach alpha?',
#  'What is the difference between patients with Schizophrenia with and without co-oc',
#  'How many patients were included in this study?',
#  'What is ankle contracture after Stroke due to abnormal intermuscular force transmission',
#  'What was the difference in fascicle length?',
#  'What is the pattern recognition analysis of H NMR?',
#  'What is the purpose of the study?',
#  'What is the name of the study that focuses on neonates?',
#  'What is the main reason for the differences in physiology?',
#  'What is the fetal insulin/insulin-like growth factor system?',
#  'What is the effect of maternal diabetes on fetal weight and fetal insulin/I',
#  'What is the name of the bacterium that is a bacterium that is ',
#  'What is the pathogenic mechanism of vitamin D signaling associated with?',
#  'What is the name of the CNGA1 Mutations in Japanese Population?',
#  'How many patients were recruited in this study?',
#  'Aurora Kinases as Targets in Drug-Resistant Neuroblastoma',
#  'What was the effect of the pan-aurora kinase inhibitor tozas',
#  'What is the name of the ERK and Akt Pathway?',
#  'What is the protective effect of U-II on apoptosis?',
#  'What is the Indolinone MAZ51?',
#  'What did MAZ51 cause?',
#  'What is the name of the study that focuses on Readmissions after Hospitalization for Heart',
#  'What was the primary outcome of the study?',
#  'What is the name of the protocol for the Quantitative Detection of Normalized',
#  'What is the name of the RT-PCR protocol used for swine?',
#  'What is the channel activity of the individual N- and C-lobes of cal',
#  'What is the molecule that can tether to the channel?',
#  'What is the translation of L Protease from Foot and Mouth Disease Virus Confers',
#  'What is the leader protease from?',
#  'What is the effect of Ambrisentan on the outcome of rats with liver transplantation?',
#  'What is a potent immunosuppressive agent used for allogeneic solid organ',
#  'What is the term for interventional treatment strategies of thoracic aortic path',
#  'What is the name of the aortic arch pathology that is becoming the target of',
#  'What is the pulmonary arterial pressure in patients with acute pulmonary thromboembolism',
#  'What was the embolism area measured using?',
#  'What is the AMPK signaling pathway that inhibits ER stress activation?',
#  'What was the effect of usnic acid on the endoplasmic reticulum stress',
#  'What is VAC therapy?',
#  'What is VAC therapy used for?',
#  'What is the basis for a motor assessment?',
#  'What is the OBJECTIVE of early diagnosis?',
#  'What is BBE in childhood?',
#  'What is BBE a rare affection in childhood?',
#  'What is the effect of different antihypertensive drugs on blood pressure variability in patients',
#  'What is the effect of calcium channel blockers and beta-blockers on blood pressure variability in',
#  'Prevalence of sleep disturbance in chronic pain?',
#  'How many family medicine units were randomly selected?',
#  'What is the name of the agent for refractory/relapsed acute lympho',
#  'What is the most difficult treatment for adult acute lymphocytic leukemia?',
#  'What is the Efficacy of intratumoral chemotherapy using?',
#  'What was the effect of arsenic trioxide on neurogliocytoma',
#  'What is the main cause of apoptosis?',
#  'What was the effect of saikosaponin-d on the proliferation of',
#  'What is Wortmannin apoptosis in human ovarian cancer cells?',
#  'What is the PI3K/Akt signaling pathway constitutively activated in some',
#  'What role does gut microbiota play in pathogenesis and management of allergic',
#  'What is the name of the article that has been withdrawn?',
#  'What is the name of the pericardium annuloplasty?',
#  'What is the name of the APA?',
#  'What is the name of the brain tumour that is BRAF alterations in?',
#  'What is the most common mutation in pleomorphic xanthoastro',
#  'What is the name of the treatment for advanced stage Hepatocellular Carcinoma?',
#  'What was the purpose of the study?',
#  'What is the BCLC Staging System?',
#  'What is the name of the open-access article distributed under the terms of the Creative Commons',
#  'What is the term for late Toxicity and Outcomes in Prostate Cancer Patients',
#  'How many Gy/25 fractions were IMRT prescribed?',
#  'What is the TGF-beta receptor/Smad pathway?',
#  'What is the transforming growth factor?',
#  'What is the comparison between Propofol, Etomidate and Thiopental in',
#  'What is the clinical response to ECT?',
#  'What is the effect of recurrent hypoglycaemia on adrenal catecholamine release',
#  'What is the main role of elevation of plasma epinephrine in normalizing',
#  'What is galectin-3 used as a prognostic biomarker in heart',
#  'What is the name of the biomarker that was used to assess the effect of galect',
#  'What is the Yale-Brown Obsessive Compulsive Scale?',
#  'What is the most frequently applied test to assess obsessive compulsive symptoms',
#  'What is the effect of the Personality Assessment Inventory with Feigned PTSD?',
#  'What is the most effective feigning group in identifying feigning',
#  'What is the name of the sphingoid base-dependent local',
#  'What is the structural diversity of renal sulfatides?',
#  'What is the Squamous Cell Carcinoma of the Pharynx or',
#  'What was the primary endpoint of the study?',
#  'What is the name of the trial in Burkina Faso?',
#  'What is the primary endpoint of the study?',
#  'What is the pathway for innate inflammation?',
#  'What is the primary enzyme for repairing 7,8-dihydro-8-ox',
#  'What is the control of the Expansion and Differentiation of IL-10-Com',
#  'What is the role of MCs in the expansion of IL-10-competent',
#  'What is the role of Neutrophils in Posthemorrhagic Shock A',
#  'What is the main component of multiple organ dysfunction syndrome?',
#  'Campylobacter jejuni Activated Inflammasome Activation?',
#  'What is the most common cause of bacterial foodborne disease worldwide?',
#  'What is the genetic control of Gene Expression in Primary Immunocytes?',
#  'What was the most variable genes in both species?',
#  'What is the name of the novel method used for a clinical-grade expansion',
#  'What is the main cause of CLL?',
#  'What is the name of the disease that is not a relapsing-re',
#  'What is the basis of T cell recognition of myelin?',
#  'What is the case report of a patient co-infected with?',
#  'What is the effect of highly active antiretroviral therapy on HCV infection?',
#  'What is the potential treatment for non-alcoholic fatty liver disease?',
#  'What is the therapeutic potential of SIRT1 activity in the treatment of NAFLD discovered in',
#  'What is the pathophysiological and clinical approach to cirrhotic cardiomyopathy',
#  'What is a cirrhotic cardiomyopathy?',
#  'What is the cause of sleep apnoea syndrome?',
#  'What is the main role of spleen involvement in NAFLD and OSAS?',
#  'What is the standard versus limited colon resection for high risk T1 colon cancer?',
#  'What is the name of the group that recommends a colectomy in presence of high risk',
#  'What is the name of the tumor cells that are counted in colorectal cancer',
#  'What was the CTC count?',
#  'What is the SIBDQ score?',
#  'What is the main predictor of disease-related outcome in IBD patients?',
#  'What is the expression of fibroblastic growth factor, syndecan 1 and tumour nec',
#  'What is the molecular pattern of Basic Fibroblastic Growth Factor?',
#  'What is the expression profile of cytotoxic T-lymphocyte-associated antigen-4',
#  'What is the key immune-checkpoint receptor regulating T-cell activation?',
#  'What is the effect of nonsteroidal anti-inflammatory drugs on the benefit of Colorec',
#  'What is a key component of the Enhanced Recovery After Surgery protocols?',
#  'What is the RE-AIM framework?',
#  'What is hypnosis capable of helping individuals with a wide variety of problems?',
#  'What is the relationship between Functional Competence and Real World Functional Performance in Schizophrenia',
#  'What is the relationship between interpersonal competence and interpersonal performance?',
#  'What is the name of the program that is developed for young adults with schizophrenia?',
#  'What is the name of the study that provides an initial proof of concept for online social cognition',
#  'What is the ACTIVITY of ENDOTHELIN-1 SYTEM?',
#  'What is the metabolic factor that is a vasoconstrictor peptid',
#  "What is the Burden among Male Alzheimer's Caregivers?",
#  'What is the most common coping strategy for AD caregivers?',
#  'What is the purpose of Personalizing Behavioral Interventions Through Single-Patient (N',
#  'What is the effect of an intervention on one group of patients?',
#  'What is the name of the research that focuses on the management of Microbial Infections',
#  'What is the name of the major driving force behind the advancement of nanomedicine?',
#  'What is the tertiary care center experience?',
#  'What is the incidence of de novo ITPAs in HCC?',
#  'What is the structure-activity analysis of a CFTR channel potentiator?',
#  'What is the most common CF mutation?',
#  'What is the name of the research that is conducted in low- and middle-income countries?',
#  'What is the highest risk of HIV/HCV infection?',
#  'What is the name of the emerging drug problem in Asia?',
#  'What was the topic of this session?',
#  'What is the living heart project?',
#  "What is the heart's most vital organ?",
#  'What is the name of the treatment for acute coronary syndrome patients?',
# ...
#  'What is the term for chevron shape?',
#  'What is the protective antibody response of mice with live-attenuated late liver stage-',
#  'What is the most effective method to confer sterile protection against malaria?',
#  'What is the goal-directed learning and obsessive-compulsive disorder',
#  'What is the case of goal-directed dysfunction in psychiatry?',
#  'What is the wait for treatment of an acutely painful knee?',
#  'What was the name of the patient who was referred to our clinic?',
#  'What is the Fatal Waterhouse-Friderichsen syndrome?',
#  'What is the main cause of death in a matter of hours?',
#  'What is the bronchoalveolar lavage fluid that is characterized by late-',
#  'What was the MTX-induced pneumonitis?',
#  'What is the name of the other name of the name of the name of the name of the',
#  'What was the true diagnosis of bony ankylosis?',
#  'What is CT diagnosis of an iatrogenic bile duct injury?',
#  'What is a complication of cholecystectomy?',
#  'What is the biology of radiosurgery and its clinical applications for brain tumors?',
#  'What is the role of SRS in brain tumor care established?',
#  'What does Nebivolol lower in?',
#  'What is the relative contribution of nebivolol to the blood pressure-',
#  'What causes the increase in Muscle Sympathetic Nerve Activity?',
#  'What is the cause of fetal programming induced by prenatal hypoxia?',
#  'What is the effect of Hypoglycemia on Brain Structure in People With Type 2 Diabetes',
#  'What was the effect of hypoglycemia related to treatment of type 2 diabetes mell',
#  'Immunoglobulin E plays an immunoregulatory role in lupus.',
#  'What is the effect of IgE on nonallergic inflammatory diseases?',
#  'What is the name of the ovarian laser evaporation?',
#  'What is the main outcome measure?',
#  'What is the ovarian reserve status?',
#  'What is the risk of developing cardiovascular disease?',
#  'What is the morphokinetic study in the mouse?',
#  'What is the frequency of complete hatching in the control group?',
#  'What is the name of the group that identifies a homogeneous subpop',
#  'What is the AMH threshold for women with PCOM?',
#  'What is the result of randomized trials?',
#  'What is the difference between "insiders" and "outsiders"?',
#  'What is the Vietnam Experience Study?',
#  'What is the highest level of Ig?',
#  'What did changes in drug reimbursement after the Medicare Modernization Act affect?',
#  'What was the odds ratio for CRC?',
#  'What is the Phase I/II Study of the Antibody-Drug Conjugate',
#  'What is the first study of glembatumumab vedot',
#  'What is the primary function of a single-agent Graft-Versus-',
#  'How many adult patients received related allografts?',
#  'What is the status of Human Papillomavirus?',
#  'What is the surrogate marker of oncogenic human papillomavirus',
#  'What is the Cognitive Function After Initiation of Adjuvant Endocrine Therapy in',
#  'What was the NP test outcome of the study?',
#  'What is the name of the soft tissue Sarcoma committee?',
#  'What was the average FFS rate for patients with subset-one low-risk embryon',
#  'What is the utility of Routine Post-Therapy Surveillance Imaging in D',
#  'What was the MER identified in?',
#  'What is the NCIC-CTG LY.12.',
#  'What was the response rate for the intention-to-treat population?',
#  'What is the association of Electrocardiographic Left Ventricular Hypertrophy with Incident Cardio',
#  'What was the incidence of CVD events?',
#  'What does Impaired Fasting Glucose and Impaired Glucose',
#  'How many subjects were enrolled in the Korean Genome Epidemiology Study?',
#  'What is the name of the case series?',
#  'How many military patients were treated after diagnosis with acupuncture?',
#  'What is the treatment used in a tertiary referral centre?',
#  'How many patients were diagnosed with metastatic phaeo/PGL?',
#  'What is the potential role of the Y-Chromosome Gene in Sexual Dimorph',
#  'What is the most important disease gene?',
#  'What is the Glutamate Transporter EAAT1?',
#  'What is the effect of EAAT1 on the synaptic glutamate concentration?',
#  'What is the cause of cancer and mortality in patients from the Simvastatin and Eze',
#  'How many patients were eligible for follow-up?',
#  'What is the Harmonized Protocol for manual hippocampal segmentation on magnetic resonance?',
#  'What is the HarP?',
#  'Radiation exposure to anaesthetists during endovascular procedures.',
#  'What is the median radiation dose emitted by fluoroscopic equipment?',
#  'What is the current status of Quantitative Susceptibility Mapping?',
#  'What is the new technique for quantifying magnetic susceptibility?',
#  'What is the effect of golden-angle KWIC with generalized kinetic model analysis on',
#  'What was the true AUC value for 10mm benign and 20mm malignant lesions?',
#  'What is Yogurt used for treating acute gastroenteritis in children?',
#  'What was the risk of bias assessed using the Cochrane risk of bias tool?',
#  'What is the role of Gender and Distance Mentoring in the Surgical Education Research Fellowship?',
#  'What was the median distance between mentor-mentee pairs that completed the SERF program?',
#  'What is the result of a vincristine blockade of posterior crico',
#  'What was the new treatment for acute unilateral vocal-fold paralysis?',
#  'What is the Mini-Mental State Examination?',
#  "What was the MMSE's overall sensitivity and specificity estimate?",
#  'What does Aortic Valve Replacement reduce?',
#  'What is the index of global left ventricular afterload?',
#  'What is the result of the analysis of Vascular Closure Devices after Transbrachial',
#  'What was the incidence of thrombotic?',
#  'What type of isolates are Neisseria gonorrhoeae',
#  'What is the blaTEM-135 gene?',
#  'What is the spectrum of activity and mechanism of resistance of Various Nucleoside Deriv',
#  'What is the susceptibility of gamma-herpesviruses?',
#  'What is the polymerase Inhibitor BMS-791325?',
#  'What is BMS-791325 a candidate for?',
#  'What effect of fluorescent dyes on in-vitro differentiated, late-stage Pla',
#  'What is the name of the two compounds that were highly active against gametocytes?',
#  'What is the Extent of Community Versus Hospital-associated Transmission in an Endemic Setting?',
#  'What is the highest resolution typing method available for transmission epidemiology?',
#  'What is the contribution of Complex polymorphisms in the Plasmodium falcip',
#  'What is the most diverse ABC transporter known in P. falciparum?',
#  'What is the Host-Targeted Antimicrobial Agent?',
#  "What was AR-12's ability to eradicate intracellular Salmonella?",
#  'What is the Pharmacokinetics and Pharmacodynamics of (+) and (-)',
#  'What was PQ a racemic mixture?',
#  'What is the effect of Oral Tigecycline Treatment on Clostridium difficile In',
#  'What was the effect of oral tigecycline treatment on Clostridium difficile infection?',
#  'What is the new data in critically ill patients suggesting an alternative loading dose rational?',
#  'What is the last line defense therapy against Multi Drug Resistant Gram-negative bacteria?',
#  'What is the peptide register in human subjects with autoimmune diabetes?',
#  'What is the importance of antigenic peptides with low-affinity HLA binding',
#  'What effect did Massive isotopic effect in vacuum UV photodissociation of N',
#  'What is the range of delta15N in extraterrestrial materials?',
#  'What is the memory trace and timing mechanism localized to?',
#  'What is the standard view of the mechanisms underlying learning?',
#  'What is the name of the network that connects invasive and noninvasive brain stimulation across diverse',
#  'What is the term for invasive approaches?',
#  'What is the type I of mucopolysaccharidosis?',
#  'What is the genetic deficiency of the lysosomal enzyme alpha',
#  'What is the therapeutic effect of fusion protein?',
#  'What is the cause of the lysosomal storage disease?',
#  'What is the proinflammatory phenotype of the immune-checkpoint VISTA gene',
#  'What is the negative checkpoint regulator that suppresses T cell-mediated immune responses?',
#  'What causes malignant progression of prostate cancer?',
#  'What is the chemokine that is a chemokine that is a',
#  'What is the molecular target for triple negative breast cancer?',
#  'What is the name of the ICAM-IONP probe?',
#  'What is the microRNA content of exosomes?',
#  'What is the source of miRNA biomarkers in bodily fluids?',
#  'What is the effect of PDGF-CC mediated by?',
#  'What is the potential vascular protective factor?',
#  'What is the name of the nanoparticles that target and kill tumors?',
#  'What is the HFn nanocarrier ideal for?',
#  'What is the name of the lineage oncogene that provides therapeutic targets for high-',
#  'What is the name of the target of ASCL1?',
#  'Antigen affinity and antigen dose exert distinct influences on CD4 T-cell differentiation.',
#  'What is the difference between high antigen affinity and antigen dose?',
#  'What is the direction of epidural needles predicts?',
#  'What was the name of the group that was randomized to two groups of 4 cadavers',
#  'What is the design of smart home sensor visualizations for older adults?',
#  'What is the goal of the design of sensor visualizations?',
#  'What is the focus of the research on point-of-care testing strategies and programs for HIV',
#  'What is the role of Point-of-care testing in communities, home settings and primary healthcare',
#  'What is residential treatment effective for opioid use disorders?',
#  'What is the most common benefit of residential treatment?',
#  'What is the Glycogene Mutation Map?',
#  'What is the name of the group that encoding Glycosylation of proteins and ',
#  'What is the name of the symptoms of gastroesophageal and extraesoph',
#  'How many controls were surveyed?',
#  'What is the name of the U.S. Armed Forces?',
#  'What is the most common sexual complaint reported by men to healthcare providers?',
#  'What is a retrospective study of docetaxel or paclitaxel in patients',
#  'What was the median age of DTX?',
#  'What is the treatment that helps with Mycoplasma pneumoniae infections?',
#  'What is the common cause of respiratory tract infections?',
#  'What is the effect of ultrasound measurements on the thickness of abdominal muscles?',
#  'What is the reversal time of the postprandial thickness of lateral abdominal',
#  'What is the sign associated with Stroke Severity?',
#  'What was the median age of all patients undergoing intravenous thrombolysis?',
#  'What is the expression of B-cell Lymphoma 2 in Rats?',
#  'What was the expression of Bcl-2 in BMSCs + oxiracet',
#  'What is the frequency of TERT promoter mutations in primary tumors of the liver?',
#  'What is the most frequent genetic alteration in hepatocellular carcinoma known at this time',
#  'What is the PRIMERI study?',
#  'What was the LV ejection fraction of LV?',
#  'What is the name of the two districts general hospitals that merge into one?',
#  'What is the aim of mathematical modelling?',
#  'Pallidifloside D, a saponin glycoside constituent from smila',
#  'What is the name of the saponin glycoside called?',
#  'What is the patented Shensong Yangxin capsule?',
#  'What was the effect of SSYX on myocardial fibrosis in',
#  'What effect did Ecliptae herba extract have on pre-osteocla',
#  'What is the effect of wedelolactone on proliferation of RAW264.7 cells',
#  'In vitro study of the impact of mechanical tension on the dermal fibroblast phen',
#  'What is the effect of exogenous mechanical tension on skin wound healing?',
#  'What was the result of a combination of BAX and CDKN1A polymorph',
#  'What was the recurrence rate in patients with GA genotype?',
#  'What is the prognostic significance of Smad3, Smad4, Smad3 ',
#  'What is the function of Smad3 complexly regulated by?',
#  'What is the EEG for neurological prognostication after cardiac arrest?',
#  'What is the name of the TTM-trial?',
#  'What is the cause of pulmonary rheumatoid nodules?',
#  'What was the result of DMARD treatment?',
#  'What is the name of the Phospholipase A2 Receptor Auto',
#  'What was the median follow-up time of all patients in the study?',
#  'What is the qualitative of survey reporting in Nephrology Journals?',
#  'What was the primary objective of the study?',
#  'What is the difference between lognormal means?',
#  'What is the method of variance estimates recovery?',
#  'Brinzolamide plus brimonidine for treatment of glaucoma: an',
#  'What is a common sight-threatening condition that is primarily treated by lowering intrao',
#  'What is the potential value of comprehensive geriatric assessment?',
#  'What was the goal of the pilot study?',
#  'What is Pain Management for Children during Bone Marrow and Stem Cell Transplantation?',
#  'What is a well-tolerated modality for pain control during hospitalization for transplant',
#  'Dominant Cystoid Macular Dystrophy',
#  'What was the first retinal abnormalities detectable in DCMD?',
#  'What is the name of the thrombotic microangiopathy and podocytopathy',
#  'What is the first agent of this class?',
#  'What is the high resolution profile of single CKpos/CD45neg Flow',
#  'What was the PCR assay for?',
#  'What was the name of the Chinese inpatients?',
#  'How many inpatient medical records were completed by 11 different hospitals nationwide in 2008 and 2011?',
#  'What is the imaging of metal-on-metal hip arthroplasties?',
#  'What was the sensitivity of CT for diagnosis of pseudotumor?',
#  'What is the tyrphostin called?',
#  'What is the tyrosine kinase inhibitor that suppresses IRS',
#  'What is the use of magnetic resonance cholangiopancreatography?',
#  'What was the goal of this study?',
#  'What is the effect of job rotation on musculoskeletal complaints?',
#  'How many studies were included in the systematic review?',
#  'What is the Correlation Between Clinicopathological Features?',
#  'What is the PI3K/AKT pathway activated by?',
#  'What is the Synthesis of [ O ]-curcumin?',
#  'What is Curcumin?',
#  'What is an anti-thyroid thioureylene?',
#  'What is the underlying cause of PTU?',
#  'What is the potential mediator of the relationship between exercise and depressive symptoms?',
#  'What is the hypothalamic-pituitary-adrenal axi',
#  'What is the platelet-rich plasma protocol for preparation of canine platelet concentrates?',
#  'What was the median PLT count in BC-PC?',
#  'What is the role of Cytokine Responses during Influenza Virus Pathogenesis',
#  'What is the name of the new strategies that can be used to curb innate immune responses?',
#  'What is the generalized pustular psoriasis associated with?',
#  'What is the rare and severe variant of psoriasis?',
#  'What is the minimum amount of salvage blood required for the use of two different autotransfusion devices',
#  'What is the minimum volume of blood returned?',
#  'What was the cause of cyclooxygenase-1 ubiquitination',
#  'What was the influence of serum Ub on platelet functions?',
#  'What is the role of VTIQ as a new tissue strain analytics measurement?',
#  'What was the mean shear wave velocity for normal testicular tissue?',
#  'What is the effect of exercise on blood fluidity?',
#  'What was the goal of the study?',
#  'What is the impact of Di(2-ethylhexyl)phthalate',
#  'What is the name of the study that seeks to determine the effects of deHP on blood',
#  'Correlation of axial blood velocity to venular and arteriolar diameter in',
#  'What was the difference between axial blood velocity and microvessel diameter?',
#  'What is the name of the drug interactions between Pharmacokinetic and Pharmacodynamic drugs',
#  'What is the most likely theoretical compounds that would lead to a clinically significant pharmaco',
#  'What is the difference between patients with Lumbar Spinal Canal Stenosis and Asymptomatic',
#  'What was the aim of the case-controlled study?',
#  'What is the name of the anti-CD25 drug?',
#  'How many patients were treated with ATL?',
#  'What is Bordetella pertussis?',
#  'What is the most common cause of pertussis?',
#  'What is the name of the immunomodulation in Stem Cell Differentiation into Neuron',
#  'What are the immunophenotypes of different stem cell types?',
#  'What is the framework of translational ethics?',
#  'What is the term for translational ethics?',
#  ...]

# %%
first_10_rows_df.head()
# Out:
#                                             question  \
# 0  What is the resurgent sodium current in mouse ...
# 1  What isoform is a locus for inherited spinocer...
# 2  What is the name of the study that focuses on ...
# 3  What was the code for anaphylactic shock unspe...
# 4  What is the cost of Fever Evaluation Cost and ...
#
#                                              context
# 0  FGF14 modulates resurgent sodium current in mo...
# 1  Rapid firing of cerebellar Purkinje neurons is...
# 2  [Drug-related Anaphylactic Shocks: Under-repor...
# 3  Aim. To evaluate the value of research in the ...
# 4  Fever Evaluation Cost and Time to Treatment in...

# %%
## HErE JUST IMPORTiNG THE PACKAGES
# Load your dataset
#dataset = load_dataset("ruslanmv/ai-medical-dataset")

# Convert the 'train' split to a pandas DataFrame
df = dataset["train"].to_pandas()

# Now you can use pandas operations on the DataFrame 'df'
# For example:
# df['clean_abstract'] = df['train'].apply(lambda x: clean_text(x)).apply(lambda x: remove_stopwords(x))
# Assuming clean_text and remove_stopwords are defined functions

# %%
##STOP WORDS IN NLP DONT MEAN ANYTHING LIKE WE THEY THEY JUST COMPLETE THE SENTENCE

## THIS IS CLASS THAT Cleans the data related to STIs
class STIDataPreprocessor:
    """
    Preprocessor for Sexually Transmitted Infections (STI) medical data.

    This class handles cleaning, normalization, and preparation of text data
    related to STIs for use in a medical chatbot.
    """

    def __init__(self):
        """Initialize the preprocessor with necessary NLTK downloads."""
        nltk.download('punkt', quiet=True)
        nltk.download('stopwords', quiet=True)
        self.stop_words = set(stopwords.words('english'))

        # STI-specific terms to keep even if they're in stopwords
        self.sti_terms = {'hiv', 'aids', 'std', 'sti', 'hpv', 'hsv'}
        self.stop_words = self.stop_words - self.sti_terms

    def clean_text(self, text: str) -> str: #str) -> str: this part is more developed skill level can do without in python but in Ctt C sharp need it
    #"""" is a multi-line comment


        """
        Clean and normalize the input text.

        Args:
            text (str): Raw input text

        Returns:
            str: Cleaned and normalized text
        """

        if pd.isna(text):
            return ""

        # Convert to lowercase
        text = text.lower()

        # Remove special characters but keep medical symbols
        text = re.sub(r'[^a-zA-Z0-9\s+\-/%]', '', text)

        # Remove extra whitespace
        text = ' '.join(text.split())

        return text

    def remove_stopwords(self, text: str) -> str:
        """
        Remove stopwords from the text, keeping STI-specific terms.

        Args:
            text (str): Input text

        Returns:
            str: Text with stopwords removed
        """
        words = word_tokenize(text) ### this is resulting in a list of words was converting sentence / paragraph into a list of words

        filtered_words = [word for word in words if word.lower() not in self.stop_words]
        return ' '.join(filtered_words)

    def preprocess_dataframe(self, df: pd.DataFrame) -> pd.DataFrame:
        """
        Preprocess the entire dataframe.

        Args:
            df (pd.DataFrame): Input dataframe with 'train' and 'results' columns

        Returns:
            pd.DataFrame: Preprocessed dataframe
        """
        # change columns names depending which csv file you are using cleaning text and removing stopwords
        df['clean_abstract'] = df['question'].apply(self.clean_text).apply(self.remove_stopwords)
        df['clean_full_text'] = df['context'].apply(self.clean_text).apply(self.remove_stopwords)

        # Combine cleaned abstract and results or full_texts depending on which csv you are using
        df['combined_text'] = df['clean_abstract'] + ' ' + df['clean_full_text']

        return df

    def prepare_for_model(self, text: str, max_length: int = 512) -> str: ##looks at paragraph, cuts the paragraph if more than 512 This takes the sentence splits to words and has a max length
        """
        Prepare text for model input, truncating if necessary.

        Args:
            text (str): Input text
            max_length (int): Maximum number of words

        Returns:
            str: Prepared text
        """
        words = text.split()
        if len(words) > max_length:
            return ' '.join(words[:max_length])
        return text

# %%
def preprocess_dataframe(self, df): ###USUALLY YOU SEE SELF IN A CLASS This allows you to code attributes in a class
    """
    Preprocess the entire dataframe.

    Args:
        df (pd.DataFrame or DatasetDict): Input dataframe with 'abstract' and 'results' columns

    Returns:
        pd.DataFrame: Preprocessed dataframe
    """

    # Check if df is a DatasetDict object-- When we try to find dataset Dict- that means we havent converted it to pandas and cleaning whole dataset


    if isinstance(df_1, datasets.DatasetDict):
        # Process each split separately and combine into a DataFrame
        all_data = []
        for split in df_1:
                    # Assuming all splits have the same columns
                    # Process the columns in each split
            df_split = df_1[split].to_pandas()  # Convert to DataFrame

            df_split['clean_abstract'] = df_split['question'].apply(self.clean_text).apply(self.remove_stopwords)
            df_split['clean_full_text'] = df_split['context'].apply(self.clean_text).apply(self.remove_stopwords)
            df_split['combined_text'] = df_split['clean_abstract'] + ' ' + df_split['clean_full_text']

            all_data.extend(df_split.to_dict('records')) # Add processed data to the list

        processed_df_1= pd.DataFrame(all_data) # Create a new DataFrame from the combined data

    else:  # If it's a regular DataFrame, process as before
        processed_df_1= df.copy()  # Create a copy to avoid modifying the original DataFrame
        processed_df_1['clean_abstract'] = processed_df_1['question'].apply(self.clean_text).apply(self.remove_stopwords)
        processed_df_1['clean_full_text'] = processed_df_1['context'].apply(self.clean_text).apply(self.remove_stopwords)
        processed_df_1['combined_text'] = processed_df_1['clean_abstract'] + ' ' + processed_df_1['clean_full_text']

    return processed_df_1  # Return the processed data

# %%
# Example usage
def main():
    # Load your DataFrame
    df_1 = pd.read_csv('pmc_dataset.csv')  # choose a csv file

    # Initialize the preprocessor
    preprocessor = STIDataPreprocessor()

    # Preprocess the data
    processed_df = preprocessor.preprocess_dataframe(first_10_rows_df)

    # Prepare a sample for model input
    sample_text = processed_df['combined_text'].iloc[0]
    model_ready_text = preprocessor.prepare_for_model(sample_text)

    print("Sample preprocessed and model-ready text:")
    print(model_ready_text[:200] + "...")  # Print first 200 characters

if __name__ == "__main__":
    main()

# %%
# Usage
# df_1= pd.read_csv('pmc_dataset.csv')

# %%
# df_2= pd.DataFrame(dataset)

# df_2.head()

# %%
# print(first_10_rows_df.head())  # Display the first few rows
# print(first_10_rows_df.columns)  # Show available columns

# %%
# !pip install -q gradio
# !pip install sacremoses
import gradio as gr
from google.colab import drive
drive.mount('/content/drive')

# %%
# Create a function that takes in a message.
# def run(msg):
#     return f'Returning this message: {msg}'


# Create an instance of the Gradio Interface application function with the following parameters.
app = gr.Interface(fn=run, inputs="text", outputs="text")

# Launch the app
app.launch()

# %%
  # processed_df_2 = chatbot.preprocess_data(df_2
  #processed_df_2 = chatbot.preprocess_data(df_2)



# df_2 = load_dataset("ruslanmv/ai-medical-dataset")
  chatbot = STIChatbot()
  processed_df_1 = chatbot.preprocess_data(first_10_rows_df)




# Example usage
# context_1 = processed_df_1['combined_text'].iloc[0]
context_2 = processed_df_1['combined_text']
summary = chatbot.generate_summary("context")
question = "What are the main symptoms of gonorrhea?"
answer = chatbot.answer_question(summary, question)
print(f"Q: {question}\nA: {answer}")

# %%
import gradio as gr

# Initialize the chatbot and preprocess the data
chatbot = STIChatbot()
processed_df_1 = chatbot.preprocess_data(first_10_rows_df)

# Function to handle the summary and answering the question
def generate_response(question):
    if not question.strip():
        return "Please enter a valid question."

    try:
        context_2 = processed_df_1['combined_text'].iloc[0]
        summary = chatbot.generate_summary(context_2)
        answer = chatbot.answer_question(summary, question)
        return answer
    except Exception as e:
        return f"An error occurred while processing your request: {str(e)}"

# Create a Gradio interface
iface = gr.Interface(
    fn=generate_response,            # The function to call
    inputs=gr.Textbox(label="Your Question", placeholder="Ask about symptoms..."),  # Input type
    outputs=gr.Textbox(label="Answer"),        # Output type
    title="Symptoms Q&A",  # Title of the interface
    description="Ask about the main symptoms you are concerned with."
)

# Launch the Gradio app
iface.launch(share=True)  # Set share=True if you want a public link

# %%
# import gradio as gr

# # Initialize the chatbot and preprocess the data
# chatbot = STIChatbot()
# processed_df_1 = chatbot.preprocess_data(first_10_rows_df)

# # Function to handle the summary and answering the question
# def generate_response(question):
#     try:
#         context_2 = processed_df_1['combined_text'].iloc[0]
#         summary = chatbot.generate_summary(context_2)
#         answer = chatbot.answer_question(summary, question)
#         return answer
#     except Exception as e:
#         return f"An error occurred: {str(e)}"

# # Create a Gradio interface
# iface = gr.Interface(
#     fn=generate_response,            # The function to call
#     inputs=gr.Textbox(label="Your Question"),  # Input type
#     outputs=gr.Textbox(label="Answer"),        # Output type
#     title="Symptoms Q&A",  # Title of the interface
#     description="Ask about the main symptoms you are concerned with."
# )

# # Launch the Gradio app
# iface.launch()
